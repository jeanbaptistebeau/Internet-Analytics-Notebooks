# %% [markdown]
# # Code snippets
#
# A collection of small code snippets that can be helpful for some parts of the lab.

# %%
import numpy as np

# %% [markdown]
# ## Spark

# %%
import json
from operator import itemgetter

# %%
# Each line can be transformed into a Python dict using `json.loads`.
data = sc.textFile("/ix/ml-20m/movies.txt").map(json.loads)

datum = data.take(1)[0]
print(datum)
print(datum["title"])
print(datum["genres"][2])
# Out:
# {'movieId': 1, 'title': 'Toy Story (1995)', 'genres': ['Adventure', 'Animation', 'Children', 'Comedy', 'Fantasy']}
# Toy Story (1995)
# Children

# %%
# `itemgetter` can be useful to extract certain fields.
datum = data.map(itemgetter("movieId", "title")).take(1)[0]

print(datum)
# Out:
# (1, 'Toy Story (1995)')

# %% [markdown]
# It is easy to append additional data to an RDD using `union`.

# %%
data = sc.textFile("/ix/ml-20m/ratings.txt").map(json.loads)

# `parallelize` transforms a Python list into an RDD.
additional = sc.parallelize([
    {"movieId": 1, "userId": 1, "timestamp": 98765, "rating": 5.0},
    {"movieId": 2, "userId": 1, "timestamp": 98765, "rating": 5.0},
])

# This will simply extend the `data` RDD with the `additional` RDD.
combined = data.union(additional)

# %% [markdown]
# The method `join` can be used to "merge" two RDDs based on the key.

# %%
ratings1 = sc.parallelize([
        (("user1", "movie7"), 3),
        (("user2", "movie4"), 4),
    ])
ratings2 = sc.parallelize([
        (("user1", "movie7"), 2.75),
        (("user2", "movie4"), 4.17),
    ])

joined = ratings1.join(ratings2).collect()

for key, val in joined:
    print(key, val)
# Out:
# ('user1', 'movie7') (3, 2.75)
# ('user2', 'movie4') (4, 4.17)

# %% [markdown]
# ## Visualization
#
# Matplotlib can be used for simple static plots.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use("ggplot")

# %%
ys1 = np.random.randn(100)
ys2 = np.sort(ys1)

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 3), sharey=True)
ax1.plot(ys1)
ax1.set_title("Unsorted")
ax2.plot(ys2)
ax2.set_title("Sorted")

# %% [markdown]
# Bokeh is another library that can be used for interactive plots.

# %%
from bokeh.io import show, output_notebook
from bokeh.plotting import figure, ColumnDataSource
from bokeh.models import HoverTool, ResetTool, PanTool, WheelZoomTool, SaveTool
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="6dd6d0fc-5cf9-417d-8d9b-1cc2d8396b0f">Loading BokehJS ...</span>
#     </div>

# %%
data = (
    (0.7, -0.3, "car", 0.1, 0),
    (-0.1, -0.5, "train", 0.3, 1),
    (-0.5, 0.7, "plane", 0.6, 2),
    (0.2, 0.2, "bike", 0.9, 3),
)

# %%
# Continuous colors
from matplotlib.colors import rgb2hex 
cmap = plt.get_cmap('viridis')
def val2rgb(val):
    return rgb2hex(cmap(val)[:3])

source = ColumnDataSource(
    data={
        "x": [x[0] for x in data],
        "y": [x[1] for x in data],
        "name": [x[2] for x in data],
        "color": [val2rgb(x[3]) for x in data],
    })

hover = HoverTool(
    tooltips=[
        ("Name", "@name"),
    ])
tools = [hover, ResetTool(), PanTool(), WheelZoomTool(), SaveTool()]

p = figure(plot_width=960, plot_height=360, tools=tools, title="Mouse over the dots")
p.circle("x", "y", source=source, size=20, color="color", alpha=0.5)
show(p, notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="126689ca-9553-4b81-895a-049deefaba67"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#126689ca-9553-4b81-895a-049deefaba67").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("3fc95c50-115e-401f-8029-65d4cf67cda9", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("126689ca-9553-4b81-895a-049deefaba67");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '126689ca-9553-4b81-895a-049deefaba67' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"3b3fc341-332e-4e44-b84a-109b4a03ef06":{"roots":{"references":[{"attributes":{"formatter":{"id":"d3f23452-dbe1-4f4d-8c62-2aa7616211e7","type":"BasicTickFormatter"},"plot":{"id":"fe9e5a63-3c0f-4f8f-bf9c-7033d8a8f40b","subtype":"Figure","type":"Plot"},"ticker":{"id":"e5b8c355-0e1f-49e5-bf94-2ccb505cacbd","type":"BasicTicker"}},"id":"c0359d49-5d4f-47d5-b524-3e97d8975755","type":"LinearAxis"},{"attributes":{},"id":"a5a1fa24-ddae-48d0-9811-889d23a322b1","type":"BasicTicker"},{"attributes":{},"id":"e5b8c355-0e1f-49e5-bf94-2ccb505cacbd","type":"BasicTicker"},{"attributes":{},"id":"74c8a9d3-77a1-4015-9ae4-974d2fc160e7","type":"BasicTickFormatter"},{"attributes":{},"id":"ef730e21-197d-4b5e-bc0b-364b8f9e3f81","type":"ToolEvents"},{"attributes":{"plot":{"id":"fe9e5a63-3c0f-4f8f-bf9c-7033d8a8f40b","subtype":"Figure","type":"Plot"}},"id":"2e6174e5-f18c-4083-81f5-4c6a4f64cf5b","type":"ResetTool"},{"attributes":{"callback":null,"column_names":["y","color","name","x"],"data":{"color":["#482475","#355f8d","#22a884","#bddf26"],"name":["car","train","plane","bike"],"x":[0.7,-0.1,-0.5,0.2],"y":[-0.3,-0.5,0.7,0.2]}},"id":"9f0c0d0a-5e7d-4b14-b6df-853cecdb6fdf","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"field":"color"},"line_alpha":{"value":0.5},"line_color":{"field":"color"},"size":{"units":"screen","value":20},"x":{"field":"x"},"y":{"field":"y"}},"id":"776fb188-8de1-4c17-9b38-446bd6a195fc","type":"Circle"},{"attributes":{"dimension":1,"plot":{"id":"fe9e5a63-3c0f-4f8f-bf9c-7033d8a8f40b","subtype":"Figure","type":"Plot"},"ticker":{"id":"e5b8c355-0e1f-49e5-bf94-2ccb505cacbd","type":"BasicTicker"}},"id":"eb06043e-93ee-41cc-87bc-0e4adff5eccc","type":"Grid"},{"attributes":{"plot":{"id":"fe9e5a63-3c0f-4f8f-bf9c-7033d8a8f40b","subtype":"Figure","type":"Plot"},"ticker":{"id":"a5a1fa24-ddae-48d0-9811-889d23a322b1","type":"BasicTicker"}},"id":"0668de01-88e3-4543-b53d-94adf0561aba","type":"Grid"},{"attributes":{"callback":null,"plot":{"id":"fe9e5a63-3c0f-4f8f-bf9c-7033d8a8f40b","subtype":"Figure","type":"Plot"},"tooltips":[["Name","@name"]]},"id":"6d74b4bb-dd94-45b0-ab89-15c120d4f3f3","type":"HoverTool"},{"attributes":{"formatter":{"id":"74c8a9d3-77a1-4015-9ae4-974d2fc160e7","type":"BasicTickFormatter"},"plot":{"id":"fe9e5a63-3c0f-4f8f-bf9c-7033d8a8f40b","subtype":"Figure","type":"Plot"},"ticker":{"id":"a5a1fa24-ddae-48d0-9811-889d23a322b1","type":"BasicTicker"}},"id":"4435d3d7-9375-40b3-a33a-18c80e24c0dd","type":"LinearAxis"},{"attributes":{"callback":null},"id":"2ff2fc50-ec40-490e-add9-4df5e1c3d58e","type":"DataRange1d"},{"attributes":{"callback":null},"id":"18e0d027-916f-44f9-9299-e7a72a6b788c","type":"DataRange1d"},{"attributes":{"plot":{"id":"fe9e5a63-3c0f-4f8f-bf9c-7033d8a8f40b","subtype":"Figure","type":"Plot"}},"id":"1d032f6f-0787-4c28-95c1-f34adf82a9c7","type":"SaveTool"},{"attributes":{"data_source":{"id":"9f0c0d0a-5e7d-4b14-b6df-853cecdb6fdf","type":"ColumnDataSource"},"glyph":{"id":"776fb188-8de1-4c17-9b38-446bd6a195fc","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"79a6d87b-7ce3-4d0e-a25e-62467caee749","type":"Circle"},"selection_glyph":null},"id":"d2dd3f39-a70b-427b-9ee9-8dfed8b5d7e5","type":"GlyphRenderer"},{"attributes":{"below":[{"id":"4435d3d7-9375-40b3-a33a-18c80e24c0dd","type":"LinearAxis"}],"left":[{"id":"c0359d49-5d4f-47d5-b524-3e97d8975755","type":"LinearAxis"}],"plot_height":360,"plot_width":960,"renderers":[{"id":"4435d3d7-9375-40b3-a33a-18c80e24c0dd","type":"LinearAxis"},{"id":"0668de01-88e3-4543-b53d-94adf0561aba","type":"Grid"},{"id":"c0359d49-5d4f-47d5-b524-3e97d8975755","type":"LinearAxis"},{"id":"eb06043e-93ee-41cc-87bc-0e4adff5eccc","type":"Grid"},{"id":"d2dd3f39-a70b-427b-9ee9-8dfed8b5d7e5","type":"GlyphRenderer"}],"title":{"id":"cdb092d8-d81d-4c82-8997-8fd8eb8dbf3b","type":"Title"},"tool_events":{"id":"ef730e21-197d-4b5e-bc0b-364b8f9e3f81","type":"ToolEvents"},"toolbar":{"id":"cc237471-fab0-4ece-af75-692bdda215c1","type":"Toolbar"},"x_range ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[11]</strong>&gt;</code></p>

# %%
# Categorial colors
from bokeh.palettes import Dark2_8

source = ColumnDataSource(
    data={
        "x": [x[0] for x in data],
        "y": [x[1] for x in data],
        "name": [x[2] for x in data],
        "color": [Dark2_8[x[4]] for x in data],
    })

hover = HoverTool(
    tooltips=[
        ("Name", "@name"),
    ])
tools = [hover, ResetTool(), PanTool(), WheelZoomTool(), SaveTool()]

p = figure(plot_width=960, plot_height=360, tools=tools, title="Mouse over the dots")
p.circle("x", "y", source=source, size=20, color="color", alpha=0.5)
show(p, notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="c1cbe931-ebb0-4327-8a10-ff666a487815"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#c1cbe931-ebb0-4327-8a10-ff666a487815").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("9ed697d2-6600-4b5c-b911-e134cddfc88a", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c1cbe931-ebb0-4327-8a10-ff666a487815");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c1cbe931-ebb0-4327-8a10-ff666a487815' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"53e959f9-8073-4a9d-ab0b-2d97d282e86d":{"roots":{"references":[{"attributes":{"dimension":1,"plot":{"id":"8fd75895-9d8e-41b0-843c-7c8f6e60cb4a","subtype":"Figure","type":"Plot"},"ticker":{"id":"6d5a9f40-7cc3-469c-9e78-6486667bae17","type":"BasicTicker"}},"id":"9d03d84b-f295-4df5-bdde-657014405b43","type":"Grid"},{"attributes":{"callback":null},"id":"ae0b82f9-79c8-4b26-bdbd-262905d72c23","type":"DataRange1d"},{"attributes":{"callback":null,"plot":{"id":"8fd75895-9d8e-41b0-843c-7c8f6e60cb4a","subtype":"Figure","type":"Plot"},"tooltips":[["Name","@name"]]},"id":"d1079594-4c8a-4dcb-8762-078ddfe4f7f5","type":"HoverTool"},{"attributes":{"plot":{"id":"8fd75895-9d8e-41b0-843c-7c8f6e60cb4a","subtype":"Figure","type":"Plot"},"ticker":{"id":"96e2aea7-e36f-43b5-8197-e4e148610e11","type":"BasicTicker"}},"id":"47ac16a5-ed16-45ef-86b2-563df98c3f29","type":"Grid"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"field":"color"},"line_alpha":{"value":0.5},"line_color":{"field":"color"},"size":{"units":"screen","value":20},"x":{"field":"x"},"y":{"field":"y"}},"id":"ea5f0d72-c2db-4e85-8649-fadc6926dbb9","type":"Circle"},{"attributes":{},"id":"96e2aea7-e36f-43b5-8197-e4e148610e11","type":"BasicTicker"},{"attributes":{"below":[{"id":"96ca753d-260f-4605-83a8-756d03f3af1f","type":"LinearAxis"}],"left":[{"id":"f1ef4e13-5cb4-4086-9307-df58f0230fb8","type":"LinearAxis"}],"plot_height":360,"plot_width":960,"renderers":[{"id":"96ca753d-260f-4605-83a8-756d03f3af1f","type":"LinearAxis"},{"id":"47ac16a5-ed16-45ef-86b2-563df98c3f29","type":"Grid"},{"id":"f1ef4e13-5cb4-4086-9307-df58f0230fb8","type":"LinearAxis"},{"id":"9d03d84b-f295-4df5-bdde-657014405b43","type":"Grid"},{"id":"86851c5a-35d9-4247-ba12-7f8e1b9f4e09","type":"GlyphRenderer"}],"title":{"id":"62679336-924c-4256-9767-2ab31aa12816","type":"Title"},"tool_events":{"id":"edc64a3a-452f-44b0-a63d-7b0bef7116cd","type":"ToolEvents"},"toolbar":{"id":"8a2a402d-aaa6-4716-a3ba-80837917b03f","type":"Toolbar"},"x_range":{"id":"2d36d174-5bde-4501-b56f-56a348fae969","type":"DataRange1d"},"y_range":{"id":"ae0b82f9-79c8-4b26-bdbd-262905d72c23","type":"DataRange1d"}},"id":"8fd75895-9d8e-41b0-843c-7c8f6e60cb4a","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null},"id":"2d36d174-5bde-4501-b56f-56a348fae969","type":"DataRange1d"},{"attributes":{"plot":{"id":"8fd75895-9d8e-41b0-843c-7c8f6e60cb4a","subtype":"Figure","type":"Plot"}},"id":"e0fdb5ab-58d2-4066-b751-ee412ec7e4a6","type":"SaveTool"},{"attributes":{},"id":"acda2936-b862-43d0-a995-5fd00a1fcc09","type":"BasicTickFormatter"},{"attributes":{},"id":"edc64a3a-452f-44b0-a63d-7b0bef7116cd","type":"ToolEvents"},{"attributes":{"formatter":{"id":"29a6c2bd-9192-4836-b687-d88685a4db13","type":"BasicTickFormatter"},"plot":{"id":"8fd75895-9d8e-41b0-843c-7c8f6e60cb4a","subtype":"Figure","type":"Plot"},"ticker":{"id":"6d5a9f40-7cc3-469c-9e78-6486667bae17","type":"BasicTicker"}},"id":"f1ef4e13-5cb4-4086-9307-df58f0230fb8","type":"LinearAxis"},{"attributes":{"plot":null,"text":"Mouse over the dots"},"id":"62679336-924c-4256-9767-2ab31aa12816","type":"Title"},{"attributes":{"plot":{"id":"8fd75895-9d8e-41b0-843c-7c8f6e60cb4a","subtype":"Figure","type":"Plot"}},"id":"9e525132-e393-4bda-bc82-c2276d8f4f8b","type":"ResetTool"},{"attributes":{},"id":"29a6c2bd-9192-4836-b687-d88685a4db13","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"c11d4413-66ab-409e-bb09-59c2ef3b6861","type":"ColumnDataSource"},"glyph":{"id":"ea5f0d72-c2db-4e85-8649-fadc6926dbb9","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"ba8bee2e-ec02-490c-9dba-574bc7118d87","type":"Circle"},"selection_glyph":null},"id":"86851c5a-35d9-4247-ba12-7f8e1b9f4e09","type":"GlyphRenderer"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"d1079594-4c8a-4dcb-8762-078ddfe4f7f5","type":"HoverTool"},{"id":"9e525132-e393-4bda-bc82-c2276d8f4f8b","type":"ResetTool"},{"id":"66752244-ffc6-4696-b97e-c15a60bb8e8c","type ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[12]</strong>&gt;</code></p>

# %% [markdown]
# ## Serialization
#
# The `pickle` module can be used to read and write Python objects from / to disk.

# %%
import pickle

# %%
# Reading an object from disk.
with open("selected-movies.pickle", "rb") as f:
    movies = pickle.load(f, encoding="utf-8")
    
for movie in movies[:3]:
    print(movie)
# Out:
# (780, 'Independence Day (a.k.a. ID4) (1996)', 0.6)
# (5349, 'Spider-Man (2002)', 0.89)
# (2571, 'Matrix, The (1999)', 0.87)

# %%
# Writing an object to disk.
data = {"a": np.arange(10), "b": np.random.randn(10)}
with open("sample-file.pickle", "wb") as f:
    pickle.dump(data, f)
